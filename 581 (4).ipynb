# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
TbrightBB = 822
TbrightKoltsa = 800
U = np.array([21.7, 25.2, 30.48, 34.63, 39.57, 58.29, 74.36, 100.5, 127.5])
I = np.array([0.672, 0.717, 0.779, 0.831, 0.887, 1.07, 1.224, 1.436, 1.644])
W = U*I
Tbright = np.array([922, 1022, 1122, 1222, 1322, 1422, 1522, 1622, 1722])
T = 1.05*Tbright-20

# %%
fig1 = plt.figure()
plt.plot(T, W**0.25, '*')

x=np.linspace(10,1000, 10000)

# %%
plt.plot(T, W, '.')
plt.xscale('log')
plt.yscale('log')
